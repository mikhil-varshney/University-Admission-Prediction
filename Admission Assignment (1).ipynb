# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# hide warnings
import warnings
warnings.filterwarnings('ignore')

# %%
Admission_df = pd.read_csv('C:\\Users\\Hp\\Downloads\\Udemy Courses\\Admission.csv')
Admission_df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Admission Chance
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
Admission_df.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Admission Chance
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
Admission_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Admission Chance   400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
Admission_df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Admission Chance
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# 25%      3.000000    8.170000    0.000000          0.640000
# 50%      3.500000    8.610000    1.000000          0.730000
# 75%      4.000000    9.062500    1.000000          0.830000
# max      5.000000    9.920000    1.000000          0.970000

# %%
Admission_df = Admission_df.drop(['Serial No.'], axis = 1)

# %%
Admission_df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Admission Chance
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
Columns_header = Admission_df.columns.values

# %%
Columns_header
# Out:
# array(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ',
#        'CGPA', 'Research', 'Admission Chance'], dtype=object)

# %%
# Admission_df.columns

# %%
i = 1
fig , ax = plt.subplots(2,4 , figsize=(20,10))

for Column_header in Columns_header:
    plt.subplot(2,4,i)
    sns.distplot(Admission_df[Column_header])
    i = i + 1

# %%
plt.figure(figsize = (10,10))

sns.heatmap(Admission_df.corr(), annot = True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(Admission_df)

# %%
i = 1
fig , ax = plt.subplots(2,4 , figsize=(20,20))

for Column_header in Columns_header:
    plt.subplot(2,4,i)
    sns.boxplot(Admission_df[Column_header])
    i = i + 1

# %%
Admission_df.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Admission Chance     0
# dtype: int64

# %%
X = Admission_df.drop(['Admission Chance'], axis = 1)

# %%
X.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0

# %%
y = Admission_df['Admission Chance']

# %%
y.head()
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Admission Chance, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, y_train, y_test = train_test_split(X , y , test_size=0.3 , random_state=100)

# %%
X_train.shape
# Out:
# (280, 7)

# %%
X_test.shape
# Out:
# (120, 7)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept=True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff(m)', regressor.coef_)
print('Linear Model Coeff(c)', regressor.intercept_)
# Out:
# Linear Model Coeff(m) [ 0.00121019  0.00340458  0.00682749 -0.01007827  0.02723971  0.12879782
#   0.02301431]
# Linear Model Coeff(c) -1.228285398131014

# %%
y_predict = regressor.predict(X_test)

# %%
plt.scatter(y_test , y_predict, color= 'r')
plt.ylabel('Model predict')
plt.xlabel('Ground Truth')
plt.show()

# %%
from sklearn.metrics import r2_score , mean_squared_error, mean_absolute_error
from math import sqrt

k = X_test.shape[1]
n = len(X_test)
RMSE = float(format(np.sqrt(mean_squared_error(y_test, y_predict)) , '.3f'))
MSE = mean_squared_error(y_test, y_predict)
MAE = mean_absolute_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
MAPE = np.mean( np.abs((y_test - y_predict) /y_test ) ) * 100

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2, '\nMean Absolute Percentage Error =', MAPE, '%')
# Out:
# RMSE = 0.061
# MSE = 0.003716513784197384
# MAE = 0.04692878285488935
# R2 = 0.8003159611553707
# Adjusted R2 = 0.7878357087275814
# Mean Absolute Percentage Error = 7.190823505768461 %
